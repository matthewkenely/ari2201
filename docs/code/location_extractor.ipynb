# %%
import numpy as np
import pandas as pd
import re

from nltk.tokenize import word_tokenize

# %%
csv = 'newsbook_articles2.csv'

# %%
df = pd.read_csv(csv)

# %%
with open('locations.txt', 'r') as f:
    locations = f.read().split('\n')

locations = [location.lower() for location in locations]

# %%
def contains_location(text):
    for word in word_tokenize(text):
        if word in locations:
            return True
    return False

# %%
# filter out articles that don't contain a location

df2 = df[df['body'].apply(contains_location)]

# %%
# filter out articles that don't contain a location
df2 = df[df['body'].apply(contains_location)]

# add entities column type string
df2['location'] = ''
df2['entities'] = ''

for i, row in df2.iterrows():
    body = row['body']
    tokens = word_tokenize(body)
    location = []
    entities = []

    offset = 0
    for j, token in enumerate(tokens):
        if token.lower() in locations:
            location.append(token.capitlize())
            entities.append((offset, offset + len(token), 'LOC'))
            # print(' '.join(tokens)[offset:offset + len(token)])

        offset += len(token) + 1

    df2.at[i, 'body'] = str(' '.join(word_tokenize(body)))
    df2.at[i, 'location'] = str(location)
    df2.at[i, 'entities'] = str(entities)
# Out:
# c:\Programming\Python\Environments\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\Programming\Python\Environments\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#                                                 title                   date  \
# 2   PN submits new information exposing ‘fraud and...  May 18, 2023 11:54 AM
# 6   ‘No one believes you’ on hospitals fiasco, Gre...   May 17, 2023 7:43 PM
# 11  PA starts demolishing illegal development in P...   May 17, 2023 3:28 PM
# 12  Muscat revelations ‘textbook case of money lau...   May 17, 2023 2:13 PM
# 18  PN submits new information exposing ‘fraud and...  May 18, 2023 11:54 AM
# 21  Muscat received payments from Swiss firm that ...  May 17, 2023 10:12 AM
# 22  Occupy Justice demands reopening of Egrant inq...   May 17, 2023 9:39 AM
# 23  New Magħtab ‘hill’ a temporary stockpile of ma...   May 17, 2023 7:00 AM
# 25           PN to hold national protest on Wednesday   May 16, 2023 6:55 PM
# 26  Repubblika demands arrest of Muscat, Mizzi to ...   May 16, 2023 3:07 PM
# 27  Labour insists NAO report on hospitals concess...   May 16, 2023 2:52 PM
# 28  IM chief dismisses concerns about safety of cr...   May 16, 2023 1:25 PM
# 29  PA starts demolishing illegal development in P...   May 17, 2023 3:28 PM
# 30  Repubblika demands arrest of Muscat, Mizzi to ...   May 16, 2023 3:07 PM
# 31  Muscat revelations ‘textbook case of money lau...   May 17, 2023 2:13 PM
# 34  PN submits new information exposing ‘fraud and...  May 18, 2023 11:54 AM
# 41  Konrad Mizzi dismisses NAO report as ‘blatantl...   May 15, 2023 8:09 PM
# 50  PN submits new information exposing ‘fraud and...  May 18, 2023 11:54 AM
# 53  Seven youths charged with terrorism shared jih...   May 15, 2023 3:00 PM
# 54  Motorcyclists blame poorly designed crash barr...   May 15, 2023 1:53 PM
# 56  496 building permits approved in first three m...  May 15, 2023 11:54 AM
# 57  Two remanded in custody over thefts from parke...  May 15, 2023 11:26 AM
# 58  Tal-Ibraġ residents urge Prime Minister to sto...  May 15, 2023 10:36 AM
#
#                                                  body  \
# 2   The Nationalist Party today submitted in court...
# 6   Nationalist Party leader Bernard Grech insiste...
# 11  The Planning Authority started removing illega...
# 12  Anticorruption NGO Repubblika has once again a...
# 18  The Nationalist Party today submitted in court...
# 21  Tista ' taqra bil Malti Disgraced former prime...
# 22  Activists from Occupy Justice staged a protest...
# 23  A new ‘ hill ’ of construction waste that has ...
# 25  The Nationalist Party will be holding national...
# 26  Tista ' taqra bil Malti Repubblika asked the m...
# 27  The Labour Party continued its attempts to des...
# 28  Tista ' taqra bil Malti Road crash barriers de...
# 29  The Planning Authority started removing illega...
# 30  Tista ' taqra bil Malti Repubblika asked the m...
# 31  Anticorruption NGO Repubblika has once again a...
# 34  The Nationalist Party today submitted in court...
# 41  Former Labour minister Konrad Mizzi dismissed ...
# 50  The Nationalist Party today submitted in court...
# 53  Tista ' taqra bil Malti Seven youths who have ...
# 54  Tista ' taqra bil Malti Many have taken to Fac...
# 56  Tista ' taqra bil Malti A total of 496 buildin...
# 57  A man and a woman both aged 47 have been reman...
# 58  Tista ' taqra bil Malti A group of residents f...
#
#                                              location  \
# 2                                        ['Valletta']
# 6   ['Attard', 'Attard', 'Attard', 'Attard', 'Atta...
# 11                                          ['Pietà']
# 12                                       ['Valletta']
# 18                                       ['Valletta']
# 21                                       ['Valletta']
# 22                                       ['Floriana']
# 23                                       ['Għargħur']
# 25                                         ['Attard']
# 26                           ['Valletta', 'Valletta']
# 27  ['Attard', 'Attard', 'Attard', 'Attard', 'Atta...
# 28                                     ['Birkirkara']
# 29                                          ['Pietà']
# 30                           ['Valletta', 'Valletta']
# 31                                       ['Valletta']
# 34                                       ['Valletta']
# 41                                       ['Valletta']
# 50                                       ['Valletta']
# 53                                ['Paola', 'Attard']
# 54                                     ['Birkirkara']
# 56     ['Naxxar', 'Mellieħa', 'Balzan', 'Birkirkara']
# 57                                       ['Floriana']
# 58                                         ['Swieqi']
#
#                                              entities
# 2                               [(1329, 1337, 'LOC')]
# 6   [(4039, 4045, 'LOC'), (4169, 4175, 'LOC'), (44...
# 11                                  [(76, 81, 'LOC')]
# 12                                [(274, 282, 'LOC')]
# 18                              [(1329, 1337, 'LOC')]
# 21                              [(1482, 1490, 'LOC')]
# 22                                [(774, 782, 'LOC')]
# 23                              [(1432, 1440, 'LOC')]
# 25                              [(1751, 1757, 'LOC')]
# 26         [(1314, 1322, 'LOC'), (2153, 2161, 'LOC')]
# 27  [(211, 217, 'LOC'), (1265, 1271, 'LOC'), (1709...
# 28                                [(553, 563, 'LOC')]
# 29                                  [(76, 81, 'LOC')]
# 30         [(1314, 1322, 'LOC'), (2153, 2161, 'LOC')]
# 31                                [(274, 282, 'LOC')]
# 34                              [(1329, 1337, 'LOC')]
# 41                              [(1737, 1745, 'LOC')]
# 50                              [(1329, 1337, 'LOC')]
# 53         [(1825, 1830, 'LOC'), (2931, 2937, 'LOC')]
# 54                                [(293, 303, 'LOC')]
# 56  [(1152, 1158, 'LOC'), (1163, 1171, 'LOC'), (11...
# 57                              [(2181, 2189, 'LOC')]
# 58                                [(577, 583, 'LOC')]

# %%
# write df2 to location_articles.csv
df2.to_csv('location_articles.csv', index=False)
