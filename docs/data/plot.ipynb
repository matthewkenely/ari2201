# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loss = [
4966.054097899391,
350.22466909004163,
304.67420678725495,
252.50606971857985,
275.1590056246673,
253.55966510487127,
218.1444039745277,
171.69634813924912,
199.96594203469544,
191.4460061674813,
]

# %%
# plot loss
plt.plot(loss)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs Epoch')
# black line
plt.axhline(y=loss[-1], color='k', linestyle='--')
plt.savefig('loss.png')
plt.show()
