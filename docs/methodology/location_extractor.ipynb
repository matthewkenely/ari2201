# %%
import numpy as np
import pandas as pd
import re

from nltk.tokenize import word_tokenize

# %%
csv = 'Newsbook Article NER Dataset - all_articles.csv'

# %%
df = pd.read_csv(csv)

# %%
with open('locations.txt', 'r') as f:
    locations = f.read().split('\n')

locations = [location.lower() for location in locations]

# %%
def contains_location(text):
    for word in word_tokenize(text):
        if word.lower() in locations:
            return True
    return False

# %%
# filter out articles that don't contain a location
df2 = df[df['body'].apply(contains_location)]

# %%
# filter out articles that don't contain a location
# df2 = df[df['body'].apply(contains_location)]

# add entities column type string
df2['location'] = ''
df2['entities'] = ''

for i, row in df2.iterrows():
    # print(i)
    body = row['body']
    tokens = word_tokenize(body)
    location = []
    entities = []

    offset = 0
    for j, token in enumerate(tokens):
        if token.lower() in locations:
            location.append(token)
            # get character index in body
            start = ' '.join(tokens).find(token, offset)
            end = start + len(token)
            offset = end
            entities.append((start, end, 'LOC'))

    df2.at[i, 'body'] = ' '.join(word_tokenize(body))
    df2.at[i, 'location'] = str(location)
    df2.at[i, 'entities'] = str(entities)
# Out:
# c:\Programming\Python\Environments\anaconda\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\Programming\Python\Environments\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#                                                    link  \
# 1     https://newsbook.com.mt/en/the-way-of-light-on...
# 5     https://newsbook.com.mt/en/pn-submits-new-info...
# 11    https://newsbook.com.mt/en/no-one-believes-you...
# 16    https://newsbook.com.mt/en/pa-starts-demolishi...
# 19    https://newsbook.com.mt/en/muscat-revelations-...
# ...                                                 ...
# 5789  https://newsbook.com.mt/en/labour-accuses-joe-...
# 5791  https://newsbook.com.mt/en/government-takes-ov...
# 5793  https://newsbook.com.mt/en/help-salesian-siste...
# 5795  https://newsbook.com.mt/en/lorry-overturns-nea...
# 5796  https://newsbook.com.mt/en/sant-cassia-murder-...
#
#                                                   title  \
# 1         The Way of Light in preparation for Pentecost
# 5     PN submits new information exposing ‘fraud and...
# 11    ‘No one believes you’ on hospitals fiasco, Gre...
# 16    PA starts demolishing illegal development in P...
# 19    Muscat revelations ‘textbook case of money lau...
# ...                                                 ...
# 5789  Labour accuses Joe Ellis of breaching Constitu...
# 5791  Government takes over after Malta Marathon can...
# 5793  Help Salesian Sisters of Don Bosco raise funds...
# 5795  Lorry overturns near Marsa bridge, motorcyclis...
# 5796  Sant Cassia murder: Removal of accused’s state...
#
#                             date  \
# 1           May 18, 2023 3:40 PM
# 5          May 18, 2023 11:54 AM
# 11          May 17, 2023 7:43 PM
# 16          May 17, 2023 3:28 PM
# 19          May 17, 2023 2:13 PM
# ...                          ...
# 5789   February 16, 2022 7:50 PM
# 5791   February 16, 2022 5:43 PM
# 5793   February 16, 2022 2:20 PM
# 5795  February 16, 2022 12:54 PM
# 5796  February 16, 2022 12:26 PM
#
#                                                    body  \
# 1     In preparation for the solemnity of Pentecost ...
# 5     The Nationalist Party today submitted in court...
# 11    Nationalist Party leader Bernard Grech insiste...
# 16    The Planning Authority started removing illega...
# 19    Anti-corruption NGO Repubblika has once again ...
# ...                                                 ...
# 5789  The Labour Party is accusing Nationalist Party...
# 5791  After Transport Malta refused to authorise the...
# 5793  The Salesian Sisters of Don Bosco have launche...
# 5795  A lorry overturned near a bridge in Marsa on W...
# 5796  The statements released by a man awaiting tria...
#
#                                                location  \
# 1                                        ['Birkirkara']
# 5                                          ['Valletta']
# 11    ['Attard', 'Attard', 'Attard', 'Attard', 'Atta...
# 16                                            ['Pietà']
# 19                                         ['Valletta']
# ...                                                 ...
# 5789                                    ['Għajnsielem']
# 5791                                ['Mdina', 'Sliema']
# 5793                              ['Xgħajra', 'Sliema']
# 5795  ['Marsa', 'Cospicua', 'Msida', 'Swieqi', 'Marsa']
# 5796                                          ['Mġarr']
#
#                                                entities
# 1                                   [(252, 262, 'LOC')]
# 5                                 [(1329, 1337, 'LOC')]
# 11    [(4040, 4046, 'LOC'), (4170, 4176, 'LOC'), (44...
# 16                                    [(76, 81, 'LOC')]
# 19                                  [(275, 283, 'LOC')]
# ...                                                 ...
# 5789                                [(839, 850, 'LOC')]
# 5791         [(1190, 1195, 'LOC'), (1199, 1205, 'LOC')]
# 5793           [(518, 525, 'LOC'), (1249, 1255, 'LOC')]
# 5795  [(36, 41, 'LOC'), (245, 253, 'LOC'), (511, 516...
# 5796                                [(613, 618, 'LOC')]
#
# [2454 rows x 6 columns]

# %%
# write df2 to location_articles.csv
df2.to_csv('location_articles.csv', index=False)
